# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import expr, col
spark = SparkSession.builder.appName("Jupyter").getOrCreate()

spark

events = spark.read.option("header", "true").csv("/home/iceberg/data/events.csv").withColumn("event_date", expr("DATE_TRUNC('day', event_time)"))
devices = spark.read.option("header","true").csv("/home/iceberg/data/devices.csv")

df = events.join(devices,on="device_id",how="left")
df = df.withColumnsRenamed({'browser_type': 'browser_family', 'os_type': 'os_family'})

df.collect()
# Out:
# [Row(device_id='532630305', user_id='1037710827', referrer=None, host='www.zachwilson.tech', url='/', event_time='2021-03-08 17:27:24.241000', event_date=datetime.datetime(2021, 3, 8, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='925588856', referrer=None, host='www.eczachly.com', url='/', event_time='2021-05-10 11:26:21.247000', event_date=datetime.datetime(2021, 5, 10, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='-1180485268', referrer=None, host='admin.zachwilson.tech', url='/', event_time='2021-02-17 16:19:30.738000', event_date=datetime.datetime(2021, 2, 17, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='-1044833855', referrer=None, host='www.zachwilson.tech', url='/', event_time='2021-09-24 15:53:14.466000', event_date=datetime.datetime(2021, 9, 24, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='747494706', referrer=None, host='www.zachwilson.tech', url='/', event_time='2021-09-26 16:03:17.535000', event_date=datetime.datetime(2021, 9, 26, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='747494706', referrer=None, host='admin.zachwilson.tech', url='/', event_time='2021-02-21 16:08:17.975000', event_date=datetime.datetime(2021, 2, 21, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='-824540328', referrer=None, host='admin.zachwilson.tech', url='/', event_time='2021-09-28 17:23:14.992000', event_date=datetime.datetime(2021, 9, 28, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='-824540328', referrer=None, host='www.eczachly.com', url='/', event_time='2021-09-29 01:22:13.197000', event_date=datetime.datetime(2021, 9, 29, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='1833036683', referrer=None, host='admin.zachwilson.tech', url='/', event_time='2021-01-24 03:15:18.583000', event_date=datetime.datetime(2021, 1, 24, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='-2134824313', referrer=None, host='www.eczachly.com', url='/', event_time='2021-01-25 00:03:00.624000', event_date=datetime.datetime(2021, 1, 25, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='-906264142', user_id='-1809929467', referrer=None, host='admin.zachwilson.tech', url='/.git/HEAD', event_time='2021-02-22 01:36:52.420000', event_date=datetime.datetime(2021, 2, 22, 0, 0), browser_family='curl', os_family='Other', device_type='Other'),
#  Row(device_id='-906264142', user_id='2002285749', referrer=None, host='www.eczachly.com', url='/', event_time='2021-02-22 02:25:41.865000', event_date=datetime.datetime(2021, 2, 22, 0, 0), browser_family='curl', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='-1562965412', referrer=None, host='www.zachwilson.tech', url='/', event_time='2021-01-30 20:46:03.961000', event_date=datetime.datetime(2021, 1, 30, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='-1099860451', referrer=None, host='www.eczachly.com', url='/', event_time='2021-02-04 23:49:18.722000', event_date=datetime.datetime(2021, 2, 4, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='-906264142', user_id='1246896869', referrer=None, host='www.zachwilson.tech', url='/', event_time='2021-02-22 02:50:50.883000', event_date=datetime.datetime(2021, 2, 22, 0, 0), browser_family='curl', os_family='Other', device_type='Other'),
#  Row(device_id='-906264142', user_id='-629331502', referrer=None, host='admin.zachwilson.tech', url='/.git/HEAD', event_time='2021-02-22 23:51:44.585000', event_date=datetime.datetime(2021, 2, 22, 0, 0), browser_family='curl', os_family='Other', device_type='Other'),
#  Row(device_id='-906264142', user_id='-1913422462', referrer=None, host='www.eczachly.com', url='/', event_time='2021-02-23 00:17:18.221000', event_date=datetime.datetime(2021, 2, 23, 0, 0), browser_family='curl', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='50429624', referrer=None, host='www.eczachly.com', url='/', event_time='2022-12-28 01:38:38.653000', event_date=datetime.datetime(2022, 12, 28, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='222389292', referrer=None, host='www.zachwilson.tech', url='/', event_time='2022-12-28 05:23:21.107000', event_date=datetime.datetime(2022, 12, 28, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='-779924777', referrer=None, host='www.zachwilson.tech', url='/', event_time='2022-12-28 16:45:14.820000', event_date=datetime.datetime(2022, 12, 28, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='-779924777', referrer=None, host='www.zachwilson.tech', url='/', event_time='2022-12-28 16:45:15.021000', event_date=datetime.datetime(2022, 12, 28, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='925588856', referrer=None, host='www.zachwilson.tech', url='/', event_time='2021-05-10 18:12:43.360000', event_date=datetime.datetime(2021, 5, 10, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='-733097781', user_id='5890109', referrer=None, host='www.zachwilson.tech', url='/', event_time='2023-01-09 11:55:28.032000', event_date=datetime.datetime(2023, 1, 9, 0, 0), browser_family='curl', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='747494706', referrer=None, host='admin.zachwilson.tech', url='/', event_time='2021-05-16 17:58:16.888000', event_date=datetime.datetime(2021, 5, 16, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='747494706', referrer=None, host='www.zachwilson.tech', url='/', event_time='2021-05-17 01:17:38.313000', event_date=datetime.datetime(2021, 5, 17, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='1095049125', referrer=None, host='www.zachwilson.tech', url='/', event_time='2021-05-17 18:18:28.916000', event_date=datetime.datetime(2021, 5, 17, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='-707954698', referrer=None, host='admin.zachwilson.tech', url='/', event_time='2021-06-19 05:55:00.559000', event_date=datetime.datetime(2021, 6, 19, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='747494706', referrer=None, host='admin.zachwilson.tech', url='/', event_time='2021-06-19 15:09:19.519000', event_date=datetime.datetime(2021, 6, 19, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='-733097781', user_id='5890109', referrer=None, host='www.zachwilson.tech', url='/', event_time='2023-01-09 20:10:27.610000', event_date=datetime.datetime(2023, 1, 9, 0, 0), browser_family='curl', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='747494706', referrer=None, host='www.eczachly.com', url='/', event_time='2021-06-20 00:34:44.256000', event_date=datetime.datetime(2021, 6, 20, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='696863716', referrer=None, host='admin.zachwilson.tech', url='/', event_time='2023-01-10 04:43:49.204000', event_date=datetime.datetime(2023, 1, 10, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='553416409', referrer=None, host='www.zachwilson.tech', url='/', event_time='2023-01-14 05:25:03.497000', event_date=datetime.datetime(2023, 1, 14, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='747494706', referrer=None, host='www.zachwilson.tech', url='/', event_time='2021-06-20 08:04:32.870000', event_date=datetime.datetime(2021, 6, 20, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='-173749422', referrer=None, host='www.zachwilson.tech', url='/', event_time='2023-01-14 05:25:04.305000', event_date=datetime.datetime(2023, 1, 14, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='1193961399', referrer=None, host='admin.zachwilson.tech', url='/', event_time='2021-06-20 18:48:53.473000', event_date=datetime.datetime(2021, 6, 20, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='1193961399', referrer=None, host='admin.zachwilson.tech', url='/', event_time='2021-06-20 19:13:34.519000', event_date=datetime.datetime(2021, 6, 20, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='-1659556787', referrer=None, host='admin.zachwilson.tech', url='/', event_time='2021-06-21 13:11:01.783000', event_date=datetime.datetime(2021, 6, 21, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='1449553813', referrer=None, host='www.zachwilson.tech', url='/', event_time='2023-01-14 05:44:51.848000', event_date=datetime.datetime(2023, 1, 14, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='-1659556787', referrer=None, host='www.zachwilson.tech', url='/', event_time='2021-06-22 22:24:28.111000', event_date=datetime.datetime(2021, 6, 22, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='-1659556787', referrer=None, host='admin.zachwilson.tech', url='/', event_time='2021-06-21 16:44:10.693000', event_date=datetime.datetime(2021, 6, 21, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='-1180485268', referrer=None, host='www.eczachly.com', url='/', event_time='2021-06-24 19:25:11.754000', event_date=datetime.datetime(2021, 6, 24, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='-1180485268', referrer=None, host='www.zachwilson.tech', url='/', event_time='2021-06-24 20:04:58.038000', event_date=datetime.datetime(2021, 6, 24, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='-1524015132', referrer=None, host='www.zachwilson.tech', url='/', event_time='2021-06-27 15:07:25.482000', event_date=datetime.datetime(2021, 6, 27, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='-1180485268', referrer=None, host='www.eczachly.com', url='/', event_time='2021-06-28 16:51:11.679000', event_date=datetime.datetime(2021, 6, 28, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='-1180485268', referrer=None, host='www.zachwilson.tech', url='/', event_time='2021-06-28 17:34:44.423000', event_date=datetime.datetime(2021, 6, 28, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='747494706', referrer=None, host='www.eczachly.com', url='/', event_time='2021-06-28 20:56:57.269000', event_date=datetime.datetime(2021, 6, 28, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='747494706', referrer=None, host='www.zachwilson.tech', url='/', event_time='2021-06-28 23:55:07.146000', event_date=datetime.datetime(2021, 6, 28, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='1736348257', referrer=None, host='admin.zachwilson.tech', url='/', event_time='2021-06-29 16:36:41.687000', event_date=datetime.datetime(2021, 6, 29, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='148800943', referrer=None, host='admin.zachwilson.tech', url='/', event_time='2021-06-30 00:42:37.602000', event_date=datetime.datetime(2021, 6, 30, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='148800943', referrer=None, host='www.eczachly.com', url='/', event_time='2021-06-30 12:16:23.406000', event_date=datetime.datetime(2021, 6, 30, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='-1188109378', referrer=None, host='www.zachwilson.tech', url='/', event_time='2021-07-02 12:33:47.501000', event_date=datetime.datetime(2021, 7, 2, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='747494706', referrer=None, host='admin.zachwilson.tech', url='/', event_time='2021-07-04 14:18:15.531000', event_date=datetime.datetime(2021, 7, 4, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='747494706', referrer=None, host='www.zachwilson.tech', url='/', event_time='2021-07-04 21:19:22.232000', event_date=datetime.datetime(2021, 7, 4, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='-1180485268', referrer=None, host='admin.zachwilson.tech', url='/', event_time='2021-07-08 15:33:39.622000', event_date=datetime.datetime(2021, 7, 8, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='-1180485268', referrer=None, host='www.eczachly.com', url='/', event_time='2021-07-12 20:48:49.730000', event_date=datetime.datetime(2021, 7, 12, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='-227950717', user_id='602187535', referrer=None, host='www.eczachly.com', url='/?author=1', event_time='2021-01-03 00:03:06.542000', event_date=datetime.datetime(2021, 1, 3, 0, 0), browser_family='Apache-HttpClient', os_family='Other', device_type='Other'),
#  Row(device_id='-227950717', user_id='602187535', referrer=None, host='www.eczachly.com', url='/?author=2', event_time='2021-01-03 00:03:06.832000', event_date=datetime.datetime(2021, 1, 3, 0, 0), browser_family='Apache-HttpClient', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='-1180485268', referrer=None, host='www.zachwilson.tech', url='/', event_time='2021-07-08 18:01:16.179000', event_date=datetime.datetime(2021, 7, 8, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='-178913481', referrer=None, host='www.zachwilson.tech', url='/contact', event_time='2021-02-04 17:41:15.018000', event_date=datetime.datetime(2021, 2, 4, 0, 0), browser_family='Other', os_family='Other', device_type='Other'),
#  Row(device_id='532630305', user_id='747494706', referrer=None, host='www.zachwilson.tech', url='/', event_time='2021-01
', event_date=datetime.datetime(2021, 1, 14, 0, 0), browser_family='AhrefsBot', os_family='Other', device_type='Spider'),
#  Row(device_id='-158310583', user_id='-1829013106', referrer=None, host='www.eczachly.com', url='/', event_time='2021-01-14 08:54:23.541000', event_date=datetime.datetime(2021, 1, 14, 0, 0), browser_family='PetalBot', os_family='Other', device_type='Spider'),
#  ...]

# %%
sorted = df.repartition(10, col("event_date"))\
    .sortWithinPartitions(col("event_date"), col("host"))\
    .withColumn("event_time", col("event_time").cast("timestamp")) 

sortedTwo = df.repartition(10, col("event_date"))\
    .sort(col("event_date"), col("host"))\
    .withColumn("event_time", col("event_time").cast("timestamp")) 

sorted.show()
sortedTwo.show()
# Out:
# +-----------+-----------+--------------------+--------------------+--------------------+--------------------+-------------------+
# |    user_id|  device_id|            referrer|                host|                 url|          event_time|         event_date|
# +-----------+-----------+--------------------+--------------------+--------------------+--------------------+-------------------+
# | 1129583063|  532630305|                NULL|admin.zachwilson....|                   /|2021-01-07 09:21:...|2021-01-07 00:00:00|
# | -648945006| 1088283544|                NULL|    www.eczachly.com|                   /|2021-01-07 02:58:...|2021-01-07 00:00:00|
# |-1871780024| -158310583|                NULL|    www.eczachly.com|                   /|2021-01-07 04:17:...|2021-01-07 00:00:00|
# |  203689086| 1088283544|                NULL|    www.eczachly.com|/blog/what-exactl...|2021-01-07 10:03:...|2021-01-07 00:00:00|
# |-1180485268|  532630305|                NULL|    www.eczachly.com|                   /|2021-01-07 18:45:...|2021-01-07 00:00:00|
# | 1129583063|  532630305|                NULL|    www.eczachly.com|                   /|2021-01-07 21:57:...|2021-01-07 00:00:00|
# |-1381834161| -158310583|                NULL|    www.eczachly.com|                   /|2021-01-07 23:07:...|2021-01-07 00:00:00|
# |-1373330946|  532630305|                NULL| www.zachwilson.tech|  /api/v1/spark-post|2021-01-07 18:53:...|2021-01-07 00:00:00|
# |-1180485268|  532630305|                NULL| www.zachwilson.tech|                   /|2021-01-07 19:20:...|2021-01-07 00:00:00|
# |-1617088793| 1957784035|https://www.zachw...| www.zachwilson.tech|            /contact|2021-01-07 00:19:...|2021-01-07 00:00:00|
# |-1617088793| 1957784035|https://www.zachw...| www.zachwilson.tech|     /api/v1/contact|2021-01-07 00:19:...|2021-01-07 00:00:00|
# |-1617088793| 1957784035|https://www.zachw...| www.zachwilson.tech|            /contact|2021-01-07 00:19:...|2021-01-07 00:00:00|
# | -267976675| 1141939293|https://www.zachw...| www.zachwilson.tech|            /contact|2021-01-07 01:57:...|2021-01-07 00:00:00|
# | -267976675| 1141939293|https://www.zachw...| www.zachwilson.tech|     /api/v1/contact|2021-01-07 01:57:...|2021-01-07 00:00:00|
# | -267976675| 1141939293|https://www.zachw...| www.zachwilson.tech|            /contact|2021-01-07 01:57:...|2021-01-07 00:00:00|
# |  604069040| 1800580819|                NULL| www.zachwilson.tech|                   /|2021-01-07 02:24:...|2021-01-07 00:00:00|
# |-2135898320| 2066336516|http://www.laurel...| www.zachwilson.tech|                   /|2021-01-07 04:57:...|2021-01-07 00:00:00|
# |  -43429336|-1217993711|                NULL| www.zachwilson.tech|            /contact|2021-01-07 04:57:...|2021-01-07 00:00:00|
# | 1198758947|-1307168836|                NULL| www.zachwilson.tech|               /blog|2021-01-07 09:57:...|2021-01-07 00:00:00|
# |-1894709267| 1141939293|https://www.zachw...| www.zachwilson.tech|                   /|2021-01-07 10:12:...|2021-01-07 00:00:00|
# +-----------+-----------+--------------------+--------------------+--------------------+--------------------+-------------------+
# only showing top 20 rows
#
# +-----------+-----------+--------------------+--------------------+--------------------+--------------------+-------------------+
# |    user_id|  device_id|            referrer|                host|                 url|          event_time|         event_date|
# +-----------+-----------+--------------------+--------------------+--------------------+--------------------+-------------------+
# | 1272828233| -643696601|                NULL|admin.zachwilson....|                   /|2021-01-02 13:53:...|2021-01-02 00:00:00|
# |  747494706|  532630305|                NULL|admin.zachwilson....|                   /|2021-01-02 19:36:...|2021-01-02 00:00:00|
# | 2110046626|  898871897|                NULL|admin.zachwilson....|       /wp-login.php|2021-01-02 19:57:...|2021-01-02 00:00:00|
# | 1272828233| -643696601|                NULL|admin.zachwilson....|                   /|2021-01-02 21:05:...|2021-01-02 00:00:00|
# | 1272828233| -643696601|                NULL|admin.zachwilson....|                   /|2021-01-02 21:37:...|2021-01-02 00:00:00|
# | 1399665425|-2012543895|                NULL|    www.eczachly.com|                   /|2021-01-02 00:20:...|2021-01-02 00:00:00|
# |  125243313| -290659081|                NULL|    www.eczachly.com|                   /|2021-01-02 02:06:...|2021-01-02 00:00:00|
# |  632739597| -290659081|                NULL|    www.eczachly.com|/blog/what-exactl...|2021-01-02 02:58:...|2021-01-02 00:00:00|
# |-1780827820| -290659081|                NULL|    www.eczachly.com|                   /|2021-01-02 04:45:...|2021-01-02 00:00:00|
# |  632739597| -290659081|                NULL|    www.eczachly.com|                   /|2021-01-02 05:14:...|2021-01-02 00:00:00|
# | 1047962242| -158310583|                NULL|    www.eczachly.com|                   /|2021-01-02 11:40:...|2021-01-02 00:00:00|
# |  273700037| -290659081|                NULL|    www.eczachly.com|                   /|2021-01-02 07:51:...|2021-01-02 00:00:00|
# | 1272828233| -643696601|                NULL|    www.eczachly.com|                   /|2021-01-02 08:14:...|2021-01-02 00:00:00|
# |  210988258| 1088283544|                NULL|    www.eczachly.com|            /contact|2021-01-02 11:11:...|2021-01-02 00:00:00|
# |  273700037| -290659081|                NULL|    www.eczachly.com|                   /|2021-01-02 11:23:...|2021-01-02 00:00:00|
# |  632739597| -290659081|                NULL|    www.eczachly.com|        /sitemap.xml|2021-01-02 14:10:...|2021-01-02 00:00:00|
# |  659201289| -290659081|                NULL|    www.eczachly.com|/blog/life-of-a-s...|2021-01-02 15:53:...|2021-01-02 00:00:00|
# | 1072106763| -784483831|https://www.zachw...| www.zachwilson.tech|            /contact|2021-01-02 09:37:...|2021-01-02 00:00:00|
# | 1744817842| -223216734|                NULL| www.zachwilson.tech|/graph/stock-tick...|2021-01-02 00:23:...|2021-01-02 00:00:00|
# | 1445055201| 1957784035|https://www.zachw...| www.zachwilson.tech|            /contact|2021-01-02 10:17:...|2021-01-02 00:00:00|
# +-----------+-----------+--------------------+--------------------+--------------------+--------------------+-------------------+
# only showing top 20 rows

# %%
# .sortWithinPartitions() sorts within partitions, whereas .sort() is a global sort, which is very slow

# Note - exchange is synonymous with Shuffle

# %%
sorted = df.repartition(10, col("event_date"))\
    .sortWithinPartitions(col("event_date"), col("host"))\
    .withColumn("event_time", col("event_time").cast("timestamp")) 

sortedTwo = df.repartition(10, col("event_date"))\
    .sort(col("event_date"), col("host"))\
    .withColumn("event_time", col("event_time").cast("timestamp")) 

sorted.explain()
sortedTwo.explain()
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [user_id#17, device_id#18, referrer#19, host#20, url#21, cast(event_time#22 as timestamp) AS event_time#288, event_date#29]
#    +- Sort [event_date#29 ASC NULLS FIRST, host#20 ASC NULLS FIRST], false, 0
#       +- Exchange hashpartitioning(event_date#29, 10), REPARTITION_BY_NUM, [plan_id=294]
#          +- Project [user_id#17, device_id#18, referrer#19, host#20, url#21, event_time#22, date_trunc(day, cast(event_time#22 as timestamp), Some(Etc/UTC)) AS event_date#29]
#             +- FileScan csv [user_id#17,device_id#18,referrer#19,host#20,url#21,event_time#22] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/home/iceberg/data/events.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<user_id:string,device_id:string,referrer:string,host:string,url:string,event_time:string>
#
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [user_id#17, device_id#18, referrer#19, host#20, url#21, cast(event_time#22 as timestamp) AS event_time#296, event_date#29]
#    +- Sort [event_date#29 ASC NULLS FIRST, host#20 ASC NULLS FIRST], true, 0
#       +- Exchange rangepartitioning(event_date#29 ASC NULLS FIRST, host#20 ASC NULLS FIRST, 200), ENSURE_REQUIREMENTS, [plan_id=316]
#          +- Exchange hashpartitioning(event_date#29, 10), REPARTITION_BY_NUM, [plan_id=312]
#             +- Project [user_id#17, device_id#18, referrer#19, host#20, url#21, event_time#22, date_trunc(day, cast(event_time#22 as timestamp), Some(Etc/UTC)) AS event_date#29]
#                +- FileScan csv [user_id#17,device_id#18,referrer#19,host#20,url#21,event_time#22] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/home/iceberg/data/events.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<user_id:string,device_id:string,referrer:string,host:string,url:string,event_time:string>

# %%
# %%sql
#
# CREATE DATABASE IF NOT EXISTS bootcamp
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# DROP TABLE IF EXISTS bootcamp.events
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# DROP TABLE IF EXISTS bootcamp.events_sorted
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS bootcamp.events (
#     url STRING,
#     referrer STRING,
#     browser_family STRING,
#     os_family STRING,
#     device_family STRING,
#     host STRING,
#     event_time TIMESTAMP,
#     event_date DATE
# )
# USING iceberg
# PARTITIONED BY (years(event_date));
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
#
#
# CREATE TABLE IF NOT EXISTS bootcamp.events_sorted (
#     url STRING,
#     referrer STRING,
#     browser_family STRING,
#     os_family STRING,
#     device_family STRING,
#     host STRING,
#     event_time TIMESTAMP,
#     event_date DATE
# )
# USING iceberg
# PARTITIONED BY (years(event_date));
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
#
#
# CREATE TABLE IF NOT EXISTS bootcamp.events_unsorted (
#     url STRING,
#     referrer STRING,
#     browser_family STRING,
#     os_family STRING,
#     device_family STRING,
#     host STRING,
#     event_time TIMESTAMP,
#     event_date DATE
# )
# USING iceberg
# PARTITIONED BY (year(event_date));
# Out:
# ++
# ||
# ++
# ++

# %%
start_df = df.repartition(4, col("event_date")).withColumn("event_time", col("event_time").cast("timestamp")) \
    
first_sort_df = start_df.sortWithinPartitions(col("event_date"), col("host"))

start_df.write.mode("overwrite").saveAsTable("bootcamp.events_unsorted")
first_sort_df.write.mode("overwrite").saveAsTable("bootcamp.events_sorted")

# %%
# %%sql
#
# SELECT SUM(file_size_in_bytes) as size, COUNT(1) as num_files, 'sorted'
# FROM demo.bootcamp.events_sorted.files
#
# UNION ALL
# SELECT SUM(file_size_in_bytes) as size, COUNT(1) as num_files, 'unsorted'
# FROM demo.bootcamp.events_unsorted.files
# Out:
# +---------+-----------+----------+
# |    size | num_files |   sorted |
# +---------+-----------+----------+
# | 2896920 |         4 |   sorted |
# | 3211534 |         4 | unsorted |
# +---------+-----------+----------+

# %%
# %%sql
# SELECT SUM(file_size_in_bytes) as size, COUNT(1) as num_files FROM demo.bootcamp.events.files;
# Out:
# +---------+-----------+
# |    size | num_files |
# +---------+-----------+
# | 3145713 |         5 |
# +---------+-----------+

# %%
# %%sql
# SELECT COUNT(1) FROM bootcamp.matches_bucketed.files

# %%
# Out:
# +----------+
# | count(1) |
# +----------+
# |     3665 |
# +----------+
